# %% [markdown]
# # <span style="color:purple">Clustering: </span><span>Finding Restaurant Clusters for Retail Site Selection</span>
#
# ![clustering](img/restaurants_clustering_v2.gif "Density-based Clustering")
#
#
# ## An Example of Spatial Analysis in ArcGIS Using Density-based Clustering

# %% [markdown]
# Prospecting a successful retail location requires a thorough understanding of where people shop, dine, and linger for entertainment in a study area. One useful way to start making sense of the vast quantities of retail business information and start finding the locations that matter is to use spatial clustering to find locations with a dense retail presence.
#
# This example starts with retail business data in Pittsburgh, PA and leverages a Spatial Statistics tool in ArcGIS named [Density-based Clustering](http://pro.arcgis.com/en/pro-app/tool-reference/spatial-statistics/densitybasedclustering.htm) to separate the dense retail location data into clusters and noise. These clusters can then be the target of further analysis and potential decisions for your organization.

# %% [markdown]
# # [Spatial Analysis Methodology](http://www.esri.com/library/books/the-language-of-spatial-analysis.pdf)

# %% [markdown]
# ### 1. Ask questions:
# Formulate hypotheses and spatial
# questions.
#
# ### 2. Explore the data:
# Examine the data quality,
# completeness, and measurement limitations (scale
# and resolution) to determine the level of analysis and
# interpretation that can be supported.
#
# ### 3. Analyze and model:
# Break the problem down into
# solvable components that can be modeled. Quantify
# and evaluate the spatial questions.
#
# ### 4. Interpret the results:
# Evaluate and analyze the results
# in the context of the question posed, data limitations,
# accuracy, and other implications.
#
# ### 5. Repeat as necessary:
# Spatial analysis is a continuous
# and iterative process that often leads to further
# questions and refinements.
#
# ### 6. Present the results:
# The best information and
# analysis becomes increasingly valuable when it can be
# effectively presented and shared with a larger audience.
#
# ### 7. Make a decision:
#
# Spatial analysis and GIS are used to support the
# decision-making process. A successful spatial analysis
# process often leads to the understanding necessary to
# drive decisions and action.

# %% [markdown]
# # <span style="color:purple">1. Ask Questions</span>

# %% [markdown]
# ## Questions:

# %% [markdown]
# #### Where are the locations in Pittsburgh, PA with dense restaurant retail presence?
#
# #### Where are the clusters of restaurants with the highest average revenue?
#
# #### Are there clusters of restaurants whose collective revenue is greater than expected?
#
# #### Is there a relationship between average restaurant cluster revenue and demographics?
#
# #### Is there a relationship between average restaurant cluster revenue and transportation access?

# %% [markdown]
# ## Hypotheses:

# %% [markdown]
# ### Where are the locations in Pittsburgh, PA with dense restaurant retail presence?
#
# - Dense restaurant clusters in Pittsburgh will likely be located in the CBD.
#
# - Dense restaurant clusters in Pittsburgh will likely be located in near proximity to intersections of heavily trafficked roads.
#
# ### Where are the clusters of restaurants with the highest average revenue?
#
# - Clusters with the highest average revenue will likely be situated near downtown Pittsburgh.
# - Clusters with the highest average revenue will likely be situated in neighborhoods with higher average income levels.
# - Clusters with the highest average revenue will likely be situated along major thoroughfares and near major public transit routes.
#
# ### Are there clusters of restaurants whose collective revenue is greater than expected (i.e. revenue outliers)?
#
# - There may be clusters with collective revenue outlier values in neighborhoods with a growing population.
# - There may be clusters with collective revenue outlier values in areas that recently underwent major redevelopment.
#
# ### Is there a relationship between average restaurant cluster revenue and demographics?
#
# - When considering service areas for each restaurant, there is likely positive correlation between socioeconomic status and average cluster revenue.
#
# ### Is there a relationship between average restaurant cluster revenue and transportation access?
#
# - When considering service areas for each restaurant, there is likely positive correlation between average cluster revenue and proximity of the cluster to major thoroughfares.

# %% [markdown]
# # <span style="color:purple">2. Explore the Data</span>

# %% [markdown]
# ### Preliminary Setup

# %% [markdown]
# #### Import the needed modules, including ArcPy, the ArcGIS API for Python, and other useful modules

# %%
import arcpy
import arcgis
import pandas as pd
import os

# %% [markdown]
# #### Set reference paths to locally available data

# %%
# Path to File Geodatabase containing available data
file_geodatabase = "data//retail.gdb"

# Path to retail business data
businesses_fc = file_geodatabase + "//us_businesses_pittsburgh"
restaurants_fc = file_geodatabase + "//restaurants_pittsburgh"

# %% [markdown]
# Optional step: Parse businesses feature class by NAICS code to retrieve restaurants

# %% [markdown]
# ### Exploring data via Table

# %%
# Create a spatial dataframe (python table with geometry) out of the restaurants feature class
restaurants_sdf = arcgis.features.SpatialDataFrame.from_featureclass(restaurants_fc)
restaurants_sdf
# Out:
#       OBJECTID     LOCNUM                         CONAME             STREET  \
# 0            1  402036338                      RUDNICK'S        TEN MILE RD
# 1            2  387410335                  RIVERSIDE INN           FRONT ST
# 2            3  831505334      RIVIERA RESTAURANT LOUNGE           FRONT ST
# 3            4  907890941        KUKI CHINESE RESTAURANT           E 3RD ST
# 4            5  309912996                        DOLFI'S          RIVER AVE
# 5            6  439157900                      PIZZA HUT         REDWOOD ST
# 6            7  118627041                  JANET'S DINER  MCCLELLANDTOWN RD
# 7            8  214799900                   CHINA GARDEN  MCCLELLANDTOWN RD
# 8            9  217577758   SPORTY'S PIZZA OVEN & GRILLE            PENN ST
# 9           10  269742656                         SUBWAY         ROBERTS RD
# 10          11  300212255     JOHNNY'S FAMILY RESTAURANT             DUNLAP
# 11          12  316965672                         SAULIE          S MAIN ST
# 12          13  379284433                  COUNTRY PIZZA      THOMPSON 2 RD
# 13          14  403076167                        PAESANO          S MAIN ST
# 14          15  403988914                RIVERSIDE DINER            PENN ST
# 15          16  422091394           CONNIE PIZZAS-N-PIES            PENN ST
# 16          17  426019153                  BETTY & NAN'S  FILBERT ORIENT RD
# 17          18  427143428             MULLEN'S IRISH HUB            MAIN ST
# 18          19  459189593                  APPLE ANNIE'S          CHURCH ST
# 19          20  614075166                      PIZZA HUT      NATIONAL PIKE
# 20          21  647664945               LARDIN HOUSE INN  MCCLELLANDTOWN RD
# 21          22  831827324           DOUBLE T BAR & GRILL  MCCLELLANDTOWN RD
# 22          23  831898861        GEORGIO'S SUBS & PIZZAS            HIGH ST
# 23          24  893928549                         SUBWAY           RR 1 BOX
# 24          25  946970027                    MC DONALD'S         ROBERTS RD
# 25          26  968687756                         SUBWAY          N MAIN ST
# 26          27  118605138                      PIZZA HUT          DANIEL DR
# 27          28  118621994  GOAL POST RESTAURANT & LOUNGE    N MORGANTOWN ST
# 28          29  226915429                   TWINS TREATS    N MORGANTOWN ST
# 29          30  248313066                   RUBY TUESDAY         MATTHEW DR
# ...        ...        ...                            ...                ...
# 4996      4997  514253285                        GARDA'S     STATE ROUTE 66
# 4997      4998  544208978                 MEL'S PIZZERIA          BUTLER RD
# 4998      4999  544209794                       ATTABOYZ     S JEFFERSON ST
# 4999      5000  618872824      THERESA'S ROYLE ALLEGHENY          BUTLER RD
# 5000      5001  970387031                  VOCELLI PIZZA         S WATER ST
# 5001      5002  986413763                  HOTSPOT HOTEL        N GRANT AVE
# 5002      5003  003260080               CADET RESTAURANT    STATE ROUTE 422
# 5003      5004  118944875                 MARSHA'S PLACE  STALEYS COURTS RD
# 5004      5005  252108709              TWIN PINES TAVERN        MCGREGOR RD
# 5005      5006  427537805  VILLA ROSA ITALIAN RESTAURANT
# 5006      5007  970386413      SUPER SHOOTERS SPORTS BAR       US ROUTE 422
# 5007      5008  118959865     CHARLEY'S PLACE RESTAURANT          W MAIN ST
# 5008      5009  118959998      MAMA'S PIZZA & SOFT SERVE          W MAIN ST
# 5009      5010  316965193                 SANDWICH HOUSE             RR 422
# 5010      5011  400143168                 VALLEY GETAWAY     STATE ROUTE 85
# 5011      5012  401360941                TINAS LOG CABIN             RR 422
# 5012      5013  402545577                  MITZI'S PLACE          E MAIN ST
# 5013      5014  403546354                FOX'S PIZZA DEN       WHITE OAK RD
# 5014      5015  415340501       FROSTY'S FROZEN DELIGHTS       WHITE OAK RD
# 5015      5016  415340502    TINA'S LOG CABIN RESTAURANT             RT 422
# 5016      5017  417708702                   KEYSTONE INN               RR 2
# 5017      5018  425562338                 COUNTRY PALACE        FAIRVIEW RD
# 5018      5019  461808859                SHAFFER'S PIZZA         ELKHORN RD
# 5019      5020  607247178                         SUBWAY             3RD ST
# 5020      5021  607251600         BUZZARD'S PIZZA & SUBS   STATE ROUTE 1037
# 5021      5022  613174333               MILLER'S HOAGIES    STATE ROUTE 422
# 5022      5023  614159796              DIMAIO RISTORANTE          W MAIN ST
# 5023      5024  647054824                 OLD TYME DINER     KITTANNING AVE
# 5024      5025  690613609                FOX'S PIZZA DEN       US ROUTE 422
# 5025      5026  872614821      FINAL SCORE SPORTS SALOON     STATE ROUTE 85
#
#                  CITY STATE    STATE_NAME    ZIP  ZIP4     NAICS  \
# 0            MARIANNA    PA  Pennsylvania  15345  1080  72251117
# 1       FREDERICKTOWN    PA  Pennsylvania  15333        72251117
# 2       FREDERICKTOWN    PA  Pennsylvania  15333        72251117
# 3           BETHLEHEM    PA  Pennsylvania  18015  1306  72251117
# 4           MASONTOWN    PA  Pennsylvania  15461  1551  72251117
# 5           MASONTOWN    PA  Pennsylvania  15461        72251115
# 6           MASONTOWN    PA  Pennsylvania  15461  2504  72251117
# 7           MASONTOWN    PA  Pennsylvania  15461  2508  72251117
# 8        POINT MARION    PA  Pennsylvania  15474  1235  72251115
# 9          GRINDSTONE    PA  Pennsylvania  15442  1105  72251117
# 10           REPUBLIC    PA  Pennsylvania  15475        72251117
# 11       POINT MARION    PA  Pennsylvania  15474  1224  72251117
# 12           REPUBLIC    PA  Pennsylvania  15475        72251115
# 13          MASONTOWN    PA  Pennsylvania  15461  2044  72251115
# 14       POINT MARION    PA  Pennsylvania  15474  1234  72251117
# 15       POINT MARION    PA  Pennsylvania  15474  1235  72251115
# 16          NEW SALEM    PA  Pennsylvania  15468  1148  72251117
# 17           REPUBLIC    PA  Pennsylvania  15475        72251117
# 18       POINT MARION    PA  Pennsylvania  15474  1267  72251117
# 19         GRINDSTONE    PA  Pennsylvania  15442  1106  72251115
# 20          MASONTOWN    PA  Pennsylvania  15461  2508  72251117
# 21    MC CLELLANDTOWN    PA  Pennsylvania  15458  1101  72251117
# 22        BROWNSVILLE    PA  Pennsylvania  15417  2164  72251117
# 23          MASONTOWN    PA  Pennsylvania  15461        72251117
# 24         GRINDSTONE    PA  Pennsylvania  15442        72251117
# 25       POINT MARION    PA  Pennsylvania  15474  1219  72251117
# 26          UNIONTOWN    PA  Pennsylvania  15401  8002  72251115
# 27         FAIRCHANCE    PA  Pennsylvania  15436        72251117
# 28         FAIRCHANCE    PA  Pennsylvania  15436  1038  72251117
# 29          UNIONTOWN    PA  Pennsylvania  15401  8417  72251117
# ...               ...   ...           ...    ...   ...       ...
# 4996        FORD CITY    PA  Pennsylvania  16226  4425  72251117
# 4997       KITTANNING    PA  Pennsylvania  16201  2170  72251115
# 4998       KITTANNING    PA  Pennsylvania  16201  2409  72251117
# 4999       KITTANNING    PA  Pennsylvania  16201  4403  72251117
# 5000       KITTANNING    PA  Pennsylvania  16201  2434  72251115
# 5001       KITTANNING    PA  Pennsylvania  16201  1490  72251117
# 5002       KITTANNING    PA  Pennsylvania  16201  3546  72251117
# 5003       KITTANNING    PA  Pennsylvania  16201  3718  72251117
# 5004       KITTANNING    PA  Pennsylvania  16201  3746  72251115
# 5005       KITTANNING    PA  Pennsylvania  16201        72251117
# 5006       KITTANNING    PA  Pennsylvania  16201  4045  72251117
# 5007     RURAL VALLEY    PA  Pennsylvania  16249        72251117
# 5008     RURAL VALLEY    PA  Pennsylvania  16249        72251115
# 5009         ELDERTON    PA  Pennsylvania  15736        72251117
# 5010       KITTANNING    PA  Pennsylvania  16201  8167  72251117
# 5011         ELDERTON    PA  Pennsylvania  15736        72251117
# 5012           DAYTON    PA  Pennsylvania  16222        72251115
# 5013     RURAL VALLEY    PA  Pennsylvania  16249  3619  72251115
# 5014     RURAL VALLEY    PA  Pennsylvania  16249  3619  72251117
# 5015         ELDERTON    PA  Pennsylvania  15736        72251117
# 5016           DAYTON    PA  Pennsylvania  16222        72251117
# 5017           DAYTON    PA  Pennsylvania  16222        72251117
# 5018          MAYPORT    PA  Pennsylvania  16240        72251115
# 5019     RURAL VALLEY    PA  Pennsylvania  16249        72251117
# 5020           DAYTON    PA  Pennsylvania  16222  3914  72251115
# 5021         ELDERTON    PA  Pennsylvania  15736        72251117
# 5022     RURAL VALLEY    PA  Pennsylvania  16249        72251117
# 5023           DAYTON    PA  Pennsylvania  16222        72251117
# 5024         SHELOCTA    PA  Pennsylvania  15774  2235  72251115
# 5025           DAYTON    PA  Pennsylvania  16222  2820  72251117
#
#                             ...                         HDBRCH  EMPNUM FRNCOD  \
# 0                           ...                                    6.0
# 1                           ...                                    5.0
# 2                           ...                                    5.0
# 3                           ...                                    3.0
# 4                           ...                                   10.0
# 5                           ...                              2    23.0      M
# 6                           ...                                    5.0
# 7                           ...                                    2.0
# 8                           ...                                    2.0
# 9                           ...                              2    15.0      R
# 10                          ...                                    1.0
# 11                          ...                                    1.0
# 12                          ...                                    4.0
# 13                          ...                                    5.0
# 14                          ...                                    4.0
# 15                          ...                                    4.0
# 16                          ...                                    6.0
# 17                          ...                                    6.0
# 18                          ...                                    9.0
# 19                          ...                              2    17.0      M
# 20                          ...                                    3.0
# 21                          ...                                    3.0
# 22                          ...                                    9.0
# 23                          ...                              2     7.0      R
# 24                          ...                              2    50.0      K
# 25                          ...                              2    11.0      R
# 26                          ...                              2    18.0      M
# 27                          ...                                    6.0
# 28                          ...                                    5.0
# 29                          ...                              2    45.0      y
# ...                         ...                            ...     ...    ...
# 4996                        ...                                   47.0
# 4997                        ...                                   35.0
# 4998                        ...                                    2.0
# 4999                        ...                                   20.0
# 5000                        ...                              2    16.0
# 5001                        ...                                    5.0
# 5002                        ...                                    6.0
# 5003                        ...                                    3.0
# 5004                        ...                                    1.0
# 5005                        ...                                    6.0
# 5006                        ...                                    5.0
# 5007                        ...                                    6.0
# 5008                        ...                                    1.0
# 5009                        ...                                    5.0
# 5010                        ...                                    2.0
# 5011                        ...                                    6.0
# 5012                        ...                                    1.0
# 5013                        ...                              2    10.0      =
# 5014                        ...                                    6.0
# 5015                        ...                                    6.0
# 5016                        ...                                    6.0
# 5017                        ...                                    3.0
# 5018                        ...                                    6.0
# 5019                        ...                              2     4.0      R
# 5020                        ...                                    1.0
# 5021                        ...                                    5.0
# 5022                        ...                                    6.0
# 5023                        ...                                    8.0
# 5024                        ...                              2    10.0      =
# 5025                        ...                                    4.0
#
#       ISCODE SQFTCODE       LOC_NAME STATUS     SCORE     SOURCE  \
# 0          3        A  StreetAddress      M  100.0000  INFOGROUP
# 1                   A  StreetAddress      M   90.0938  INFOGROUP
# 2                   A  StreetAddress      M  100.0000  INFOGROUP
# 3          C        A   PointAddress      M   86.8281  INFOGROUP
# 4                   B  StreetAddress      M  100.0000  INFOGROUP
# 5                   B     StreetName      T   90.5313  INFOGROUP
# 6          t        A   PointAddress      M  100.0000  INFOGROUP
# 7          C        A   PointAddress      M  100.0000  INFOGROUP
# 8                   A  StreetAddress      M  100.0000  INFOGROUP
# 9          D        B  StreetAddress      M  100.0000  INFOGROUP
# 10                  A  StreetAddress      M   91.3906  INFOGROUP
# 11                  A  StreetAddress      M  100.0000  INFOGROUP
# 12                  A  StreetAddress      M   90.0938  INFOGROUP
# 13                  A   PointAddress      M   92.4219  INFOGROUP
# 14         t        A  StreetAddress      M  100.0000  INFOGROUP
# 15                  A  StreetAddress      M  100.0000  INFOGROUP
# 16         P        A   PointAddress      M  100.0000  INFOGROUP
# 17         M        A   PointAddress      M  100.0000  INFOGROUP
# 18                  B  StreetAddress      M  100.0000  INFOGROUP
# 19                  B   PointAddress      M  100.0000  INFOGROUP
# 20         2        A   PointAddress      M  100.0000  INFOGROUP
# 21                  A   PointAddress      M  100.0000  INFOGROUP
# 22         D        B  StreetAddress      M  100.0000  INFOGROUP
# 23         D        B  StreetAddress      M  100.0000  INFOGROUP
# 24         e        B  StreetAddress      M  100.0000  INFOGROUP
# 25         D        B  StreetAddress      M  100.0000  INFOGROUP
# 26                  B  StreetAddress      M  100.0000  INFOGROUP
# 27                  A   PointAddress      M  100.0000  INFOGROUP
# 28                  A   PointAddress      M  100.0000  INFOGROUP
# 29         3        B  StreetAddress      M  100.0000  INFOGROUP
# ...      ...      ...            ...    ...       ...        ...
# 4996       I        B  StreetAddress      M  100.0000  INFOGROUP
# 4997                B   PointAddress      M  100.0000  INFOGROUP
# 4998                A   PointAddress      M  100.0000  INFOGROUP
# 4999                B   PointAddress      M  100.0000  INFOGROUP
# 5000                B   PointAddress      M  100.0000  INFOGROUP
# 5001                A   PointAddress      M  100.0000  INFOGROUP
# 5002                A  StreetAddress      M  100.0000  INFOGROUP
# 5003                A  StreetAddress      M  100.0000  INFOGROUP
# 5004                A   PointAddress      M  100.0000  INFOGROUP
# 5005       I        A         Postal      M  100.0000  INFOGROUP
# 5006                A   PointAddress      M  100.0000  INFOGROUP
# 5007                A   PointAddress      M  100.0000  INFOGROUP
# 5008                A   PointAddress      M  100.0000  INFOGROUP
# 5009       D        A     StreetName      M   85.7031  INFOGROUP
# 5010                A   PointAddress      M  100.0000  INFOGROUP
# 5011                A         Postal      M  100.0000  INFOGROUP
# 5012                A   PointAddress      M  100.0000  INFOGROUP
# 5013                B  StreetAddress      M  100.0000  INFOGROUP
# 5014                A  StreetAddress      M  100.0000  INFOGROUP
# 5015                A     StreetName      M   97.0625  INFOGROUP
# 5016                A         Postal      M  100.0000  INFOGROUP
# 5017                A         Postal      M  100.0000  INFOGROUP
# 5018                A         Postal      M  100.0000  INFOGROUP
# 5019       D        A     StreetName      M  100.0000  INFOGROUP
# 5020                A   PointAddress      M  100.0000  INFOGROUP
# 5021       D        A   PointAddress      M   97.0625  INFOGROUP
# 5022       I        A   PointAddress      M  100.0000  INFOGROUP
# 5023       t        B   PointAddress      M  100.0000  INFOGROUP
# 5024                B   PointAddress      M  100.0000  INFOGROUP
# 5025                A   PointAddress      M  100.0000  INFOGROUP
#
#                                                   SHAPE
# 0     {'x': -8919964.005570533, 'y': 4867758.9117359...
# 1     {'x': -8905258.700836735, 'y': 4865826.0263644...
# 2     {'x': -8905314.36058214, 'y': 4866727.02381835...
# 3     {'x': -8904590.783891981, 'y': 4868224.0230725...
# 4     {'x': -8896241.822082484, 'y': 4844052.5717511...
# 5     {'x': -8895774.28022115, 'y': 4844531.07518083...
# 6     {'x': -8894527.501924265, 'y': 4845430.1438411...
# 7     {'x': -8893759.397437794, 'y': 4846532.3388230...
# 8     {'x': -8894338.258789917, 'y': 4828101.1194576...
# 9     {'x': -8890542.26415387, 'y': 4867729.84300147...
# 10    {'x': -8892056.209228657, 'y': 4860596.0439408...
# 11    {'x': -8894672.217262294, 'y': 4827768.1640337...
# 12    {'x': -8893403.175067253, 'y': 4859869.8753424...
# 13    {'x': -8894393.918535315, 'y': 4844038.0720063...
# 14    {'x': -8894449.578280712, 'y': 4828144.5492451...
# 15    {'x': -8894349.390739, 'y': 4828101.11945761, ...
# 16    {'x': -8889384.541449623, 'y': 4858693.5948817...
# 17    {'x': -8892067.341177732, 'y': 4860566.9961773...
# 18    {'x': -8894371.654637156, 'y': 4828303.7934168...
# 19    {'x': -8890931.882371644, 'y': 4867235.6875473...
# 20    {'x': -8893926.376673985, 'y': 4846474.3255170...
# 21    {'x': -8891688.854909034, 'y': 4848693.5754889...
# 22    {'x': -8894282.599044519, 'y': 4867758.9117359...
# 23    {'x': -8895752.01632299, 'y': 4844589.07715973...
# 24    {'x': -8890542.26415387, 'y': 4867584.50060682...
# 25    {'x': -8894438.44633163, 'y': 4828390.65494555...
# 26    {'x': -8878608.814740825, 'y': 4851827.4774533...
# 27    {'x': -8878163.536777662, 'y': 4840703.6915741...
# 28    {'x': -8878085.613134094, 'y': 4840689.1967055...
# 29    {'x': -8878230.328472134, 'y': 4852364.4023489...
# ...                                                 ...
# 4996  {'x': -8853773.436344847, 'y': 4971437.4882425...
# 4997  {'x': -8853662.11685406, 'y': 4984401.09493216...
# 4998  {'x': -8852081.380084794, 'y': 4984915.8789673...
# 4999  {'x': -8853817.96414117, 'y': 4984960.00457681...
# 5000  {'x': -8852148.171779273, 'y': 4984812.9199878...
# 5001  {'x': -8852103.64398295, 'y': 4985577.78406131...
# 5002  {'x': -8848886.51069902, 'y': 4983724.56292264...
# 5003  {'x': -8848474.628583089, 'y': 4986019.0790697...
# 5004  {'x': -8848519.156379411, 'y': 4986033.7892470...
# 5005  {'x': -8849008.962138897, 'y': 4984062.8230652...
# 5006  {'x': -8844578.446405323, 'y': 4980945.3908082...
# 5007  {'x': -8830830.489292355, 'y': 4982856.9057250...
# 5008  {'x': -8829249.752523094, 'y': 4982783.3789990...
# 5009  {'x': -8832500.281654252, 'y': 4967384.3794728...
# 5010  {'x': -8832544.809450574, 'y': 4983092.1949702...
# 5011  {'x': -8832266.510723587, 'y': 4967457.7904193...
# 5012  {'x': -8821056.638000706, 'y': 4994687.2178030...
# 5013  {'x': -8825865.640002979, 'y': 4977152.8767819...
# 5014  {'x': -8825865.640002979, 'y': 4977152.8767819...
# 5015  {'x': -8832500.281654252, 'y': 4967384.3794728...
# 5016  {'x': -8820889.658764523, 'y': 4993892.1948145...
# 5017  {'x': -8820889.658764523, 'y': 4993892.1948145...
# 5018  {'x': -8817895.16446218, 'y': 5017062.80294019...
# 5019  {'x': -8820166.082074365, 'y': 4979622.2535225...
# 5020  {'x': -8830785.96149604, 'y': 4990447.84429529...
# 5021  {'x': -8832500.281654252, 'y': 4967281.6050732...
# 5022  {'x': -8830875.017088676, 'y': 4982842.2003355...
# 5023  {'x': -8821646.631301912, 'y': 4994333.8662458...
# 5024  {'x': -8830062.384805882, 'y': 4964184.1976627...
# 5025  {'x': -8822381.339941151, 'y': 4982798.0842999...
#
# [5026 rows x 22 columns]

# %%
# Get list of attributes (columns)
restaurants_sdf.columns.tolist()
# Out:
# ['OBJECTID',
#  'LOCNUM',
#  'CONAME',
#  'STREET',
#  'CITY',
#  'STATE',
#  'STATE_NAME',
#  'ZIP',
#  'ZIP4',
#  'NAICS',
#  'SIC',
#  'SALESVOL',
#  'HDBRCH',
#  'EMPNUM',
#  'FRNCOD',
#  'ISCODE',
#  'SQFTCODE',
#  'LOC_NAME',
#  'STATUS',
#  'SCORE',
#  'SOURCE',
#  'SHAPE']

# %%
# Get the data types for each column
restaurants_sdf.dtypes
# Out:
# OBJECTID        int64
# LOCNUM         object
# CONAME         object
# STREET         object
# CITY           object
# STATE          object
# STATE_NAME     object
# ZIP            object
# ZIP4           object
# NAICS          object
# SIC            object
# SALESVOL      float64
# HDBRCH         object
# EMPNUM        float64
# FRNCOD         object
# ISCODE         object
# SQFTCODE       object
# LOC_NAME       object
# STATUS         object
# SCORE         float64
# SOURCE         object
# SHAPE          object
# dtype: object

# %%
# Get summary statistics on numeric fields
restaurants_sdf.describe()
# Out:
#           OBJECTID      SALESVOL       EMPNUM        SCORE
# count  5026.000000   5026.000000  5026.000000  5026.000000
# mean   2513.500000    802.645444    17.216076    99.608847
# std    1451.025557   1130.667265    24.190230     1.855258
# min       1.000000      0.000000     1.000000    85.703100
# 25%    1257.250000    280.000000     6.000000   100.000000
# 50%    2513.500000    374.000000     8.000000   100.000000
# 75%    3769.750000    888.000000    19.000000   100.000000
# max    5026.000000  14035.000000   300.000000   100.000000

# %%
# Get the restaurants with the highest sales revenue by sorting on the 'SALESVOL' column
top_sales_sdf = restaurants_sdf.sort_values(by=['SALESVOL'], ascending=False).reset_index()
print("Top 5 Restaurants in Pittsburgh by Sales Volume: ")

top_sales_sdf[['CONAME', 'SALESVOL', 'STREET', 'CITY', 'STATE', 'STATE_NAME', 'ZIP',]].head()
# Out:
# Top 5 Restaurants in Pittsburgh by Sales Volume:
#                CONAME  SALESVOL             STREET        CITY STATE  \
# 0  CHEESECAKE FACTORY   14035.0  ROSS PARK MALL DR  PITTSBURGH    PA
# 1          EAT'N PARK   12865.0      PARK MANOR DR  PITTSBURGH    PA
# 2  CHEESECAKE FACTORY   12631.0          S 27TH ST  PITTSBURGH    PA
# 3          M I FRIDAY   11695.0          PERRY HWY  PITTSBURGH    PA
# 4                NANA   11695.0      WATERFRONT DR  PITTSBURGH    PA
#
#      STATE_NAME    ZIP
# 0  Pennsylvania  15237
# 1  Pennsylvania  15205
# 2  Pennsylvania  15203
# 3  Pennsylvania  15229
# 4  Pennsylvania  15222

# %%
# Determine the top five zip codes by average restaurant sales volume

# Use groupby object to make calculations by Zip Code
zip_groupby = restaurants_sdf.groupby(restaurants_sdf['ZIP'])
# Determine means for numeric columns by zip
zip_mean_sales_df = zip_groupby.mean().sort_values(by=['SALESVOL'], ascending=False)
# Calculate Zip ranks by average sales volume
zip_mean_sales_df['Zip Ave. Sales Rank'] = zip_mean_sales_df['SALESVOL'].rank(ascending=False)
# Drop the unneeded 'SCORE' field
del zip_mean_sales_df['SCORE']

zip_mean_sales_df
# Out:
#           OBJECTID     SALESVOL     EMPNUM  Zip Ave. Sales Rank
# ZIP
# 15231  4293.818182  1862.272727  39.818182                  1.0
# 15275  3861.695652  1801.652174  38.521739                  2.0
# 15482   950.000000  1637.000000  35.000000                  3.0
# 15084  1093.789474  1524.842105  32.605263                  4.0
# 15205  3716.203540  1422.796460  30.424779                  5.0
# 15225  3822.666667  1387.333333  29.666667                  6.0
# 15120  1779.529412  1294.686275  29.647059                  7.0
# 15236  2419.912281  1274.105263  27.245614                  8.0
# 15672   626.588235  1268.058824  27.117647                  9.0
# 15044  2320.352941  1257.029412  26.882353                 10.0
# 15237  3122.731481  1256.546296  26.907407                 11.0
# 15624   324.500000  1227.500000  26.250000                 12.0
# 15238  1542.074074  1218.370370  26.055556                 13.0
# 15639   604.000000  1216.000000  26.000000                 14.0
# 15061  4519.340909  1204.068182  25.750000                 15.0
# 15241  3504.424242  1181.757576  25.272727                 16.0
# 15146  1013.027778  1179.398148  25.222222                 17.0
# 15636   704.900000  1173.800000  25.100000                 18.0
# 15626   552.888889  1166.444444  24.944444                 19.0
# 15601   442.476190  1146.115646  24.510204                 20.0
# 16066  4682.950000  1144.462500  24.475000                 21.0
# 16046  4741.843750  1128.031250  24.125000                 22.0
# 15090  3512.531915  1127.255319  24.106383                 23.0
# 15479   860.500000  1122.500000  24.000000                 24.0
# 15229  3240.884615  1098.769231  23.500000                 25.0
# 16001  4844.804348  1097.347826  23.467391                 26.0
# 15442    25.250000  1075.500000  23.000000                 27.0
# 15139  1379.125000  1063.812500  22.750000                 28.0
# 15219  2715.515152  1054.181818  22.545455                 29.0
# 15314  2938.444444  1044.333333  22.333333                 30.0
# ...            ...          ...        ...                  ...
# 18015  1838.000000   210.000000   4.500000                230.0
# 15043  4414.333333   202.000000   4.333333                231.0
# 15112  1344.571429   193.142857   4.142857                232.0
# 15684   338.000000   187.000000   4.000000                233.5
# 15082  4124.000000   187.000000   4.000000                233.5
# 15311  4067.500000   186.500000   4.000000                236.5
# 15671   248.500000   186.500000   4.000000                236.5
# 15019  4391.500000   186.500000   4.000000                236.5
# 15367  3452.500000   186.500000   4.000000                236.5
# 15632   668.400000   186.400000   4.000000                239.0
# 15089  1001.571429   179.857143   3.857143                240.0
# 16222  5019.833333   178.833333   3.833333                241.0
# 15697   552.000000   177.200000   3.800000                242.0
# 15637   833.750000   174.750000   3.750000                243.0
# 15458    40.666667   171.000000   3.666667                244.5
# 15475    14.000000   171.000000   3.666667                244.5
# 15464   187.500000   163.000000   3.500000                246.5
# 15923   206.500000   163.000000   3.500000                246.5
# 15621   355.500000   140.000000   3.000000                250.0
# 15680   386.000000   140.000000   3.000000                250.0
# 15646   253.333333   140.000000   3.000000                250.0
# 15004  4437.000000   140.000000   3.000000                250.0
# 15276  3788.000000   140.000000   3.000000                250.0
# 15014   864.333333   124.000000   2.666667                253.0
# 15432  1486.000000    93.000000   2.000000                255.5
# 15688   569.000000    93.000000   2.000000                255.5
# 16020  4863.000000    93.000000   2.000000                255.5
# 15055  3810.000000    93.000000   2.000000                255.5
# 15104  1434.600000    83.600000   1.800000                258.0
# 16229  4947.000000    46.000000   1.000000                259.0
#
# [259 rows x 4 columns]

# %% [markdown]
# ### Exploring data via maps

# %%
# Connect to ArcGIS Online
gis = arcgis.gis.GIS("https://esrifederal.maps.arcgis.com", username="Anieto_esrifederal")
# Out:
# Enter password: ········

# %%
# Create map widget
restaurants_map = gis.map("Pittsburgh")
restaurants_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
restaurants_sdf.plot(kind='map',
                     map_widget=restaurants_map,
                     marker_size=3, 
                     pallette='Greys_r',
                     symbol_style='o',
                     outline_color='Greys_r',
                     line_width=.5,
                     cstep=25)
# Out:
# True

# %%
# TODO - Change view example to published service

# %%
# Plot the highest five selling restaurants
top_five_map = gis.map("Pittsburgh")
top_sales_sdf[['CONAME', 'SALESVOL', 'STREET', 'CITY', 'STATE', 'STATE_NAME', 'ZIP','SHAPE']].head().plot(kind='map', map_widget=top_five_map)
top_five_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
# Plot the lowest five selling restaurants
bot_five_map = gis.map("Pittsburgh")
bot_sales_sdf = restaurants_sdf.sort_values(by=['SALESVOL'], ascending=True).reset_index()
bot_sales_sdf[['CONAME', 'SALESVOL', 'STREET', 'CITY', 'STATE', 'STATE_NAME', 'ZIP','SHAPE']].head().plot(kind='map', map_widget=bot_five_map)
bot_five_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %% [markdown]
# ### Exploring data via charts

# %% [markdown]
# This section will leverage plotting libraries in Python for now. When a common web charting specification is made available across ArcGIS, we could integrate an explanation of that approach in this section.

# %%
# Import needed plotting modules
import matplotlib.pyplot as plt

# %%
# Create a sales histogram
sales_histogram = restaurants_sdf.hist(column="SALESVOL")

# %%
# Create an employee count histogram
empnum_histogram = restaurants_sdf.hist(column="EMPNUM")

# %%
# Create a scatter plot of sales vs employee number
scatterplot = restaurants_sdf[['EMPNUM', 'SALESVOL']].plot(kind='scatter', x='EMPNUM', y='SALESVOL')

# %%
# Check the correlation between employee count at restaurant and sales volume at restaurant
restaurants_sdf['EMPNUM'].corr(restaurants_sdf['SALESVOL'])
# Out:
# 0.9978171595302142

# %%
# Make a box plot of the top five zip codes by sales volume

# Get top five zip codes by average sales volume
top_five_zips_list = zip_mean_sales_df.index[zip_mean_sales_df['Zip Ave. Sales Rank'] <= 5].tolist()
print("Top five Zip Codes by average sales volume: "+str(top_five_zips_list))

# Create subset table for the named cities
subset_sdf = restaurants_sdf.loc[restaurants_sdf['ZIP'].isin(top_five_zips_list)]


restaurants_pivots = subset_sdf.pivot_table(columns='ZIP', values='SALESVOL')
restaurants_pivots.plot(kind='box')
# Out:
# Top five Zip Codes by average sales volume: ['15231', '15275', '15482', '15084', '15205']

# %% [markdown]
# ### Assessment

# %% [markdown]
# To determine which analysis questions our data can support, let's recall our listed questions and assess how applicable the data currently is:

# %% [markdown]
# #### Where are the locations in Pittsburgh, PA with dense restaurant retail presence?
#
# Assessment: The data appears to have accurate restaurant locations and can be used in conjunction with analysis tools answer this question.
#
# #### Where are the clusters of restaurants with the highest average revenue?
#
# Assessment: The data appears sufficient quality for sales volume data for each restaurant, and could be used to answer this question.
#
# #### Are there clusters of restaurants whose collective revenue is greater than expected?
#
# Assessment: Since the two components mentioned above (location and sales revenue per restaurant) appear to be of good enough quality, this question is a matter of using the two components and can likely be addressed through this data.
#
# #### Is there a relationship between average restaurant cluster revenue and demographics?
#
# Assessment: We need demographic information and a method to connect each restaurant to related geographic features with accurate demographic data, as well as more specific information on which demographics we want to study relationships for. This question is proposed for a progression version of this analysis.
#
# #### Is there a relationship between average restaurant cluster revenue and transportation access?
#
# Assessment: In a similar way to the previous question, we need transportation information and a robust method to associate restaurant patronage with nearby transportation features. This question is proposed for a future version of this analysis.

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - Examine the data quality: Check for null values, check for outliers.
# - Examine location quality: Make a few cells that confirm/reject the quality of geometry for the data.
# - Trash the box plot example and determine a better way to start exploring different neighborhood distributions.

# %% [markdown]
# # <span style="color:purple">3. Analyze and model:</span>

# %% [markdown]
# Let's recall our analysis questions that survived our exploration of the data:

# %% [markdown]
# #### 1. Where are the locations in Pittsburgh, PA with dense restaurant retail presence?
#
# #### 2. Where are the clusters of restaurants with the highest average revenue?
#
# #### 3. Are there clusters of restaurants whose collective revenue is greater than expected?

# %% [markdown]
# These three questions depend on finding locations with dense restaurant retail presence, or clusters based on location. Thankfully, a tool is available to help us find these clusters:

# %% [markdown]
# ## Density-based Clustering

# %% [markdown]
# ![clustering](img/dbclustering_01.png "Density-based Clustering")

# %% [markdown]
# The [Density-based Clustering tool](http://pro.arcgis.com/en/pro-app/tool-reference/spatial-statistics/how-density-based-clustering-works.htm) works by detecting areas where points are concentrated and where they are separated by areas that are empty or sparse. Points that are not part of a cluster are labeled as noise.
#
# This tool uses unsupervised machine learning clustering algorithms which automatically detect patterns based purely on spatial location and the distance to a specified number of neighbors. These algorithms are considered unsupervised because they do not require any training on what it means to be a cluster.

# %% [markdown]
# #### Three clustering algorithms:

# %% [markdown]
# The Density-based Clustering tool provides three different Clustering Methods with which to find clusters in your point data:
#
# - _Defined distance (DBSCAN)_ — Uses a specified distance to separate dense clusters from sparser noise. The DBSCAN algorithm is the fastest of the clustering methods, but is only appropriate if there is a very clear Search Distance to use, and that works well for all potential clusters. This requires that all meaningful clusters have similar densities.
#
# - _Self-adjusting (HDBSCAN)_ — Uses a range of distances to separate clusters of varying densities from sparser noise. The HDBSCAN algorithm is the most data-driven of the clustering methods, and thus requires the least user input.
#
# - _Multi-scale (OPTICS)_ — Uses the distance between neighboring features to create a reachability plot which is then used to separate clusters of varying densities from noise. The OPTICS algorithm offers the most flexibility in fine-tuning the clusters that are detected, though it is computationally intensive, particularly with a large Search Distance.

# %% [markdown]
# ### Option 1: Run locally and load into web map widget
# #### Issue: Need to determine how to load symbology or specified renderer when working with spatial dataframes

# %%
# Run Density-based Clustering on the restaurants feature class
if arcpy.Exists("{0}//{1}_HDBSCAN".format(file_geodatabase, "Restaurants")):
    clusters_fc = "{0}//{1}_HDBSCAN".format(file_geodatabase, "Restaurants")
else:
    clusters_fc = arcpy.stats.DensityBasedClustering(restaurants_fc, "{0}//{1}_HDBSCAN".format(file_geodatabase, "Restaurants"), "HDBSCAN", 5)
clusters_fc
# Out:
# 'data//retail.gdb//Restaurants_HDBSCAN'

# %%
# Create a dataframe from the density-based clustering output
clusters_sdf = arcgis.features.SpatialDataFrame.from_featureclass(clusters_fc, sr = arcpy.SpatialReference(4326))
clusters_sdf
# Out:
#       OBJECTID  SOURCE_ID  CLUSTER_ID      PROB   OUTLIER  EXEMPLAR  \
# 0            1          1          -1  0.000000  0.027113         0
# 1            2          2          -1  0.000000  0.023014         0
# 2            3          3          -1  0.000000  0.005891         0
# 3            4          4          56  0.173037  0.826963         0
# 4            5          5          36  1.000000  0.000000         1
# 5            6          6          36  1.000000  0.000000         1
# 6            7          7          36  1.000000  0.000000         1
# 7            8          8          36  0.790149  0.209851         0
# 8            9          9           7  1.000000  0.000000         1
# 9           10         10          56  0.357273  0.642727         0
# 10          11         11          35  1.000000  0.000000         1
# 11          12         12           7  0.498830  0.501170         0
# 12          13         13          -1  0.000000  0.011129         0
# 13          14         14          36  1.000000  0.000000         1
# 14          15         15           7  1.000000  0.000000         1
# 15          16         16           7  1.000000  0.000000         1
# 16          17         17          35  1.000000  0.000000         1
# 17          18         18          35  1.000000  0.000000         1
# 18          19         19           7  1.000000  0.000000         1
# 19          20         20          56  0.344194  0.655806         0
# 20          21         21          36  0.838014  0.161986         0
# 21          22         22          36  0.508461  0.491539         0
# 22          23         23          56  0.561879  0.438121         0
# 23          24         24          36  1.000000  0.000000         1
# 24          25         25          56  0.343456  0.656544         0
# 25          26         26           7  1.000000  0.000000         1
# 26          27         27          -1  0.000000  0.255119         0
# 27          28         28          40  1.000000  0.000000         1
# 28          29         29          40  1.000000  0.000000         1
# 29          30         30          63  1.000000  0.000000         1
# ...        ...        ...         ...       ...       ...       ...
# 4996      4997       4997          -1  0.000000  0.103226         0
# 4997      4998       4998          -1  0.000000  0.175061         0
# 4998      4999       4999          11  1.000000  0.000000         1
# 4999      5000       5000          11  0.191985  0.808015         0
# 5000      5001       5001          11  1.000000  0.000000         1
# 5001      5002       5002          11  0.336729  0.663271         0
# 5002      5003       5003          10  1.000000  0.000000         1
# 5003      5004       5004          10  1.000000  0.000000         1
# 5004      5005       5005          10  1.000000  0.000000         1
# 5005      5006       5006          10  1.000000  0.000000         1
# 5006      5007       5007          -1  0.000000  0.109885         0
# 5007      5008       5008           2  1.000000  0.000000         1
# 5008      5009       5009           2  1.000000  0.000000         1
# 5009      5010       5010           3  1.000000  0.000000         1
# 5010      5011       5011           2  0.999882  0.000118         0
# 5011      5012       5012           3  1.000000  0.000000         1
# 5012      5013       5013           2  0.712546  0.287454         0
# 5013      5014       5014           2  1.000000  0.000000         1
# 5014      5015       5015           2  1.000000  0.000000         1
# 5015      5016       5016           3  1.000000  0.000000         1
# 5016      5017       5017           2  0.721675  0.278325         0
# 5017      5018       5018           2  0.721675  0.278325         0
# 5018      5019       5019          -1  0.000000  0.421425         0
# 5019      5020       5020           2  0.786247  0.213753         0
# 5020      5021       5021           2  0.967406  0.032594         0
# 5021      5022       5022           3  1.000000  0.000000         1
# 5022      5023       5023           2  0.997590  0.002410         0
# 5023      5024       5024           2  0.761452  0.238548         0
# 5024      5025       5025           3  1.000000  0.000000         1
# 5025      5026       5026           2  1.000000  0.000000         1
#
#       STABILITY  COLOR_ID                                              SHAPE
# 0           0.0        -1  {'x': -80.12939999999999, 'y': 40.012500000000...
# 1           0.0        -1  {'x': -79.99729999999992, 'y': 39.999199999999...
# 2           0.0        -1  {'x': -79.99779999999998, 'y': 40.005400000000...
# 3           0.0         7  {'x': -79.99129999999997, 'y': 40.015700000000...
# 4           0.0         4  {'x': -79.91629999999996, 'y': 39.849200000000...
# 5           0.0         4  {'x': -79.91209999999994, 'y': 39.852500000000...
# 6           0.0         4  {'x': -79.90089999999994, 'y': 39.858700000000...
# 7           0.0         4  {'x': -79.89399999999995, 'y': 39.866300000000...
# 8           0.0         8  {'x': -79.89919999999995, 'y': 39.739100000000...
# 9           0.0         7  {'x': -79.86509999999997, 'y': 40.012300000000...
# 10          0.0         3  {'x': -79.87869999999997, 'y': 39.963200000000...
# 11          0.0         8  {'x': -79.90219999999991, 'y': 39.736800000000...
# 12          0.0        -1  {'x': -79.89079999999994, 'y': 39.958200000000...
# 13          0.0         4  {'x': -79.89969999999995, 'y': 39.849100000000...
# 14          0.0         8  {'x': -79.90019999999996, 'y': 39.739400000000...
# 15          0.0         8  {'x': -79.89929999999997, 'y': 39.739100000000...
# 16          0.0         3  {'x': -79.85470000000001, 'y': 39.950100000000...
# 17          0.0         3  {'x': -79.87879999999991, 'y': 39.963000000000...
# 18          0.0         8  {'x': -79.89949999999995, 'y': 39.740500000000...
# 19          0.0         7  {'x': -79.86859999999996, 'y': 40.008900000000...
# 20          0.0         4  {'x': -79.89549999999997, 'y': 39.865900000000...
# 21          0.0         4  {'x': -79.87539999999991, 'y': 39.881200000000...
# 22          0.0         7  {'x': -79.89869999999992, 'y': 40.012500000000...
# 23          0.0         4  {'x': -79.91189999999993, 'y': 39.852900000000...
# 24          0.0         7  {'x': -79.86509999999997, 'y': 40.011300000000...
# 25          0.0         8  {'x': -79.90009999999992, 'y': 39.741100000000...
# 26          0.0        -1  {'x': -79.75789999999992, 'y': 39.902800000000...
# 27          0.0         3  {'x': -79.75390000000002, 'y': 39.826100000000...
# 28          0.0         3  {'x': -79.7531999999999, 'y': 39.8260000000001...
# 29          0.0         2  {'x': -79.75449999999996, 'y': 39.906500000000...
# ...         ...       ...                                                ...
# 4996        0.0        -1  {'x': -79.53479999999993, 'y': 40.722100000000...
# 4997        0.0        -1  {'x': -79.53379999999999, 'y': 40.810300000000...
# 4998        0.0         7  {'x': -79.51959999999997, 'y': 40.813800000000...
# 4999        0.0         7  {'x': -79.53519999999997, 'y': 40.814100000000...
# 5000        0.0         7  {'x': -79.5202, 'y': 40.81310000000006, 'spati...
# 5001        0.0         7  {'x': -79.51979999999995, 'y': 40.818300000000...
# 5002        0.0         5  {'x': -79.49089999999991, 'y': 40.805700000000...
# 5003        0.0         5  {'x': -79.48719999999993, 'y': 40.821300000000...
# 5004        0.0         5  {'x': -79.48759999999999, 'y': 40.821400000000...
# 5005        0.0         5  {'x': -79.49199999999995, 'y': 40.808000000000...
# 5006        0.0        -1  {'x': -79.45219999999993, 'y': 40.786800000000...
# 5007        0.0         6  {'x': -79.32869999999996, 'y': 40.799800000000...
# 5008        0.0         6  {'x': -79.31449999999998, 'y': 40.799300000000...
# 5009        0.0         1  {'x': -79.34369999999993, 'y': 40.694500000000...
# 5010        0.0         6  {'x': -79.34409999999997, 'y': 40.801400000000...
# 5011        0.0         1  {'x': -79.34159999999994, 'y': 40.695000000000...
# 5012        0.0         6  {'x': -79.24089999999995, 'y': 40.880200000000...
# 5013        0.0         6  {'x': -79.28409999999998, 'y': 40.761000000000...
# 5014        0.0         6  {'x': -79.28409999999998, 'y': 40.761000000000...
# 5015        0.0         1  {'x': -79.34369999999993, 'y': 40.694500000000...
# 5016        0.0         6  {'x': -79.23940000000002, 'y': 40.874800000000...
# 5017        0.0         6  {'x': -79.23940000000002, 'y': 40.874800000000...
# 5018        0.0        -1  {'x': -79.21249999999998, 'y': 41.032000000000...
# 5019        0.0         6  {'x': -79.2329, 'y': 40.777800000000106, 'spat...
# 5020        0.0         6  {'x': -79.32829999999997, 'y': 40.851400000000...
# 5021        0.0         1  {'x': -79.34369999999993, 'y': 40.693800000000...
# 5022        0.0         6  {'x': -79.32909999999998, 'y': 40.799700000000...
# 5023        0.0         6  {'x': -79.24619999999996, 'y': 40.877800000000...
# 5024        0.0         1  {'x': -79.32179999999995, 'y': 40.672700000000...
# 5025        0.0         6  {'x': -79.2528, 'y': 40.79940000000009, 'spati...
#
# [5026 rows x 9 columns]

# %%
# Publish the density-based clustering output to the GIS
fc = gis.content.import_data(clusters_sdf, title="Restaurant Clusters v1", tags="Restaurants; Clusters")
fc
# Out:
# <Item title:"Restaurant Clusters v1" type:Feature Layer Collection owner:Anieto_esrifederal>

# %%
# Retrieve data from the published service 
clusters_sdf = arcgis.features.SpatialDataFrame.from_layer(fc.layers[0])
clusters_sdf
# Out:
#       CLUSTER_ID  COLOR_ID  EXEMPLAR  OBJECTID   OUTLIER      PROB  SOURCE_ID  \
# 0             -1        -1         0         1  0.027113  0.000000          1
# 1             -1        -1         0         2  0.023014  0.000000          2
# 2             -1        -1         0         3  0.005891  0.000000          3
# 3             56         7         0         4  0.826963  0.173037          4
# 4             36         4         1         5  0.000000  1.000000          5
# 5             36         4         1         6  0.000000  1.000000          6
# 6             36         4         1         7  0.000000  1.000000          7
# 7             36         4         0         8  0.209851  0.790149          8
# 8              7         8         1         9  0.000000  1.000000          9
# 9             56         7         0        10  0.642727  0.357273         10
# 10            35         3         1        11  0.000000  1.000000         11
# 11             7         8         0        12  0.501170  0.498830         12
# 12            -1        -1         0        13  0.011129  0.000000         13
# 13            36         4         1        14  0.000000  1.000000         14
# 14             7         8         1        15  0.000000  1.000000         15
# 15             7         8         1        16  0.000000  1.000000         16
# 16            35         3         1        17  0.000000  1.000000         17
# 17            35         3         1        18  0.000000  1.000000         18
# 18             7         8         1        19  0.000000  1.000000         19
# 19            56         7         0        20  0.655806  0.344194         20
# 20            36         4         0        21  0.161986  0.838014         21
# 21            36         4         0        22  0.491539  0.508461         22
# 22            56         7         0        23  0.438121  0.561879         23
# 23            36         4         1        24  0.000000  1.000000         24
# 24            56         7         0        25  0.656544  0.343456         25
# 25             7         8         1        26  0.000000  1.000000         26
# 26            -1        -1         0        27  0.255119  0.000000         27
# 27            40         3         1        28  0.000000  1.000000         28
# 28            40         3         1        29  0.000000  1.000000         29
# 29            63         2         1        30  0.000000  1.000000         30
# ...          ...       ...       ...       ...       ...       ...        ...
# 4996          -1        -1         0      4997  0.103226  0.000000       4997
# 4997          -1        -1         0      4998  0.175062  0.000000       4998
# 4998          11         7         1      4999  0.000000  1.000000       4999
# 4999          11         7         0      5000  0.808015  0.191985       5000
# 5000          11         7         1      5001  0.000000  1.000000       5001
# 5001          11         7         0      5002  0.663271  0.336729       5002
# 5002          10         5         1      5003  0.000000  1.000000       5003
# 5003          10         5         1      5004  0.000000  1.000000       5004
# 5004          10         5         1      5005  0.000000  1.000000       5005
# 5005          10         5         1      5006  0.000000  1.000000       5006
# 5006          -1        -1         0      5007  0.109885  0.000000       5007
# 5007           2         6         1      5008  0.000000  1.000000       5008
# 5008           2         6         1      5009  0.000000  1.000000       5009
# 5009           3         1         1      5010  0.000000  1.000000       5010
# 5010           2         6         0      5011  0.000118  0.999883       5011
# 5011           3         1         1      5012  0.000000  1.000000       5012
# 5012           2         6         0      5013  0.287454  0.712546       5013
# 5013           2         6         1      5014  0.000000  1.000000       5014
# 5014           2         6         1      5015  0.000000  1.000000       5015
# 5015           3         1         1      5016  0.000000  1.000000       5016
# 5016           2         6         0      5017  0.278325  0.721675       5017
# 5017           2         6         0      5018  0.278325  0.721675       5018
# 5018          -1        -1         0      5019  0.421425  0.000000       5019
# 5019           2         6         0      5020  0.213753  0.786247       5020
# 5020           2         6         0      5021  0.032594  0.967406       5021
# 5021           3         1         1      5022  0.000000  1.000000       5022
# 5022           2         6         0      5023  0.002410  0.997590       5023
# 5023           2         6         0      5024  0.238548  0.761452       5024
# 5024           3         1         1      5025  0.000000  1.000000       5025
# 5025           2         6         1      5026  0.000000  1.000000       5026
#
#       STABILITY                                              SHAPE
# 0             0  {'x': -8919964.005570533, 'y': 4867758.9117359...
# 1             0  {'x': -8905258.700836737, 'y': 4865826.0263644...
# 2             0  {'x': -8905314.36058214, 'y': 4866727.02381835...
# 3             0  {'x': -8904590.783891981, 'y': 4868224.0230725...
# 4             0  {'x': -8896241.822082486, 'y': 4844052.5717511...
# 5             0  {'x': -8895774.280221151, 'y': 4844531.0751808...
# 6             0  {'x': -8894527.501924269, 'y': 4845430.1438411...
# 7             0  {'x': -8893759.397437792, 'y': 4846532.3388230...
# 8             0  {'x': -8894338.25878992, 'y': 4828101.11945760...
# 9             0  {'x': -8890542.264153872, 'y': 4867729.8430014...
# 10            0  {'x': -8892056.209228659, 'y': 4860596.0439408...
# 11            0  {'x': -8894672.217262296, 'y': 4827768.1640337...
# 12            0  {'x': -8893403.175067255, 'y': 4859869.8753424...
# 13            0  {'x': -8894393.918535313, 'y': 4844038.0720063...
# 14            0  {'x': -8894449.578280715, 'y': 4828144.5492451...
# 15            0  {'x': -8894349.390739001, 'y': 4828101.1194576...
# 16            0  {'x': -8889384.541449621, 'y': 4858693.5948817...
# 17            0  {'x': -8892067.341177735, 'y': 4860566.9961773...
# 18            0  {'x': -8894371.65463716, 'y': 4828303.79341687...
# 19            0  {'x': -8890931.882371644, 'y': 4867235.6875472...
# 20            0  {'x': -8893926.376673985, 'y': 4846474.3255170...
# 21            0  {'x': -8891688.854909038, 'y': 4848693.5754889...
# 22            0  {'x': -8894282.599044522, 'y': 4867758.9117359...
# 23            0  {'x': -8895752.016322993, 'y': 4844589.0771597...
# 24            0  {'x': -8890542.264153872, 'y': 4867584.5006068...
# 25            0  {'x': -8894438.446331633, 'y': 4828390.6549455...
# 26            0  {'x': -8878608.81474083, 'y': 4851827.47745330...
# 27            0  {'x': -8878163.53677766, 'y': 4840703.69157409...
# 28            0  {'x': -8878085.613134097, 'y': 4840689.1967055...
# 29            0  {'x': -8878230.328472132, 'y': 4852364.4023488...
# ...         ...                                                ...
# 4996          0  {'x': -8853773.43634485, 'y': 4971437.48824258...
# 4997          0  {'x': -8853662.11685406, 'y': 4984401.09493216...
# 4998          0  {'x': -8852081.380084794, 'y': 4984915.8789673...
# 4999          0  {'x': -8853817.96414117, 'y': 4984960.00457681...
# 5000          0  {'x': -8852148.171779271, 'y': 4984812.9199878...
# 5001          0  {'x': -8852103.643982952, 'y': 4985577.7840613...
# 5002          0  {'x': -8848886.510699024, 'y': 4983724.5629226...
# 5003          0  {'x': -8848474.628583092, 'y': 4986019.0790697...
# 5004          0  {'x': -8848519.156379411, 'y': 4986033.7892470...
# 5005          0  {'x': -8849008.962138899, 'y': 4984062.8230652...
# 5006          0  {'x': -8844578.446405325, 'y': 4980945.3908082...
# 5007          0  {'x': -8830830.489292359, 'y': 4982856.9057250...
# 5008          0  {'x': -8829249.752523093, 'y': 4982783.3789990...
# 5009          0  {'x': -8832500.281654255, 'y': 4967384.3794728...
# 5010          0  {'x': -8832544.809450574, 'y': 4983092.1949702...
# 5011          0  {'x': -8832266.51072359, 'y': 4967457.79041935...
# 5012          0  {'x': -8821056.638000706, 'y': 4994687.2178030...
# 5013          0  {'x': -8825865.640002977, 'y': 4977152.8767819...
# 5014          0  {'x': -8825865.640002977, 'y': 4977152.8767819...
# 5015          0  {'x': -8832500.281654255, 'y': 4967384.3794728...
# 5016          0  {'x': -8820889.65876452, 'y': 4993892.19481454...
# 5017          0  {'x': -8820889.65876452, 'y': 4993892.19481454...
# 5018          0  {'x': -8817895.16446218, 'y': 5017062.80294019...
# 5019          0  {'x': -8820166.082074363, 'y': 4979622.2535225...
# 5020          0  {'x': -8830785.961496038, 'y': 4990447.8442952...
# 5021          0  {'x': -8832500.281654255, 'y': 4967281.6050732...
# 5022          0  {'x': -8830875.017088676, 'y': 4982842.2003355...
# 5023          0  {'x': -8821646.631301915, 'y': 4994333.8662458...
# 5024          0  {'x': -8830062.38480588, 'y': 4964184.19766278...
# 5025          0  {'x': -8822381.33994115, 'y': 4982798.08429993...
#
# [5026 rows x 9 columns]

# %%
clusters_map = gis.map("Pittsburgh")
clusters_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
clusters_sdf.plot(kind='map', map_widget=clusters_map, renderer_type='u', col="COLOR_ID")
# Out:
# True

# %%
# arcgis.mapping.generate_renderer?

# %%
# clusters_map.add_layer(fc, {"renderer":"unique", "field_name": "COLOR_ID"})

# %% [markdown]
# ### Option 2 (Temporary): Use previously run analysis to work with inherent symbology

# %%
cluster_item = gis.content.search("HDBSCAN_restaurants_5mfc", item_type="feature service")[0]
cluster_item
# Out:
# <Item title:"HDBSCAN_restaurants_5mfc" type:Feature Layer Collection owner:albe9057@esri.com_esrifederal>

# %%
clusters_map = gis.map("Pittsburgh")
clusters_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %% [markdown]
# ### Option 3? - Run Portal/AGOL Density-based Clustering

# %% [markdown]
# ## Directional Distribution (Standard Deviational Ellipse)

# %% [markdown]
# ![ellipses](img/ellipses_01.png "Standard Deviational Ellipses")

# %% [markdown]
# While you can get a sense of the clusters by running Density-based Clustering and drawing output cluster features on a map, calculating the standard deviational ellipse makes the trend clear.

# %% [markdown]
# ### Option 1: Run locally and load into web map widget
# #### Issue: Need to determine how to load symbology or specified renderer when working with spatial dataframes

# %%
clusters_map.add_layer(cluster_item)

# %% [markdown]
# ### Option 2 (Temporary): Use previously run analysis

# %%
ellipses_item = gis.content.search("Ellipses_HDBSCAN_restaurants_5mfc", item_type="feature service")[0]
ellipses_item
# Out:
# <Item title:"Ellipses_HDBSCAN_restaurants_5mfc" type:Feature Layer Collection owner:albe9057@esri.com_esrifederal>

# %%
ellipses_map = gis.map("Pittsburgh")
ellipses_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
# Add layers to the map
ellipses_map.add_layer(cluster_item)
ellipses_map.add_layer(ellipses_item)

# %% [markdown]
# # <span style="color:purple">4. Interpret the Results:</span>

# %% [markdown]
# Let's recall our analysis questions and stated hypotheses:

# %% [markdown]
# ### Where are the locations in Pittsburgh, PA with dense restaurant retail presence?

# %% [markdown]
# #### Stated Hypotheses:

# %% [markdown]
# - Dense restaurant clusters in Pittsburgh will likely be located in the CBD.
#
# - Dense restaurant clusters in Pittsburgh will likely be located in near proximity to intersections of heavily trafficked roads.

# %% [markdown]
# #### Assessment:

# %% [markdown]
# ### Where are the clusters of restaurants with the highest average revenue?

# %% [markdown]
# #### Stated Hypotheses:

# %% [markdown]
# - Clusters with the highest average revenue will likely be situated near downtown Pittsburgh.
# - Clusters with the highest average revenue will likely be situated in neighborhoods with higher average income levels.
# - Clusters with the highest average revenue will likely be situated along major thoroughfares and near major public transit routes.

# %% [markdown]
# #### Assessment:

# %% [markdown]
# ### Are there clusters of restaurants whose collective revenue is greater than expected (i.e. revenue outliers)?

# %% [markdown]
# #### Stated Hypotheses:

# %% [markdown]
# - There may be clusters with collective revenue outlier values in neighborhoods with a growing population.
# - There may be clusters with collective revenue outlier values in areas that recently underwent major redevelopment.

# %% [markdown]
# #### Assessment:

# %% [markdown]
# ### Next Steps:

# %% [markdown]
# - Assess whether the outputs help address each analysis question.
# - Address assumptions and issues in the current iteration of the analysis.
# - Determine which refinements are needed for the next iteration.

# %% [markdown]
# # <span style="color:purple">5. Repeat as Necessary:</span>

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - Run different methods of Density-based Clustering (OPTICS, DBSCAN)
# - Determine how different parameter inputs for a single clustering method alter the results
# - Assess the three questions with each iteration.

# %% [markdown]
# # <span style="color:purple">6. Present the Results:</span>

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - Publish the final output layers.
# - Design a web map to contain the final information products that answer each question.
# - Optional: Design and launch a story map using the Python API to contain the narrative and explanation of the analysis.

# %% [markdown]
# # <span style="color:purple">7. Make a Decision:</span>

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - To be determined.
